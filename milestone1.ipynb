# %% [markdown]
# # MILESTONE 1
#
# **Assia Ouanaya, Alexandre Variengien, Félicie Giraud-Sauveur
# Data visualization project: ATP Tennis [Data Set](https://www.kaggle.com/datasets/edoardoba/atp-tennis-data)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Problematic

# %% [markdown]
# Since its creation in the nineteenth century, tennis has kept increasing in popularity to become one of the most played sports, and one of the most mediatized. You cannot ignore the names of the best figures such as Rafael Nadal or Novak Djokovic that compete in the unmissable Grand Slam tournaments: from Roland Garros to Wellington.
# Nonetheless, the usual picture of tennis shared by the media tends to focus on a tiny subset of both the events and the players.
# With this visualization, we want to give a holistic image of the community of professional tennis players, its global structure.
#
# First, we want to visualize the pattern of matchmaking through tournaments and through the seasons. All the tournaments can be seen as a graph whose nodes are the players and the edges are the tennis matches. We want to visualize the structure of this graph.
#
# In addition to the competitions, we would focus on individual players: besides the well-known superstars, what is the usual career of a professional tennis player, what are his characteristics? We want to share the stories of the ones whose names will never appear in any international headlines, while they make up the biggest chunk of the community.
# Those questions, such as the role of right or left handedness, are the subject of common discussions. Through the use of data visualization, we aim at shedding new light on these topics.
#
# This visualization is intended for the general public, with no particular interest in tennis. Our goal is to show the fascinating patterns that emerge in the data visualization from this field and to share the statistical stories that never appear in newspapers.

# %% [markdown]
# ## Dataset

# %% [markdown]
# We chose to work with the ATP Tennis with Betting Odds found on [Kaggle](https://www.kaggle.com/datasets/edoardoba/atp-tennis-data/metadata).

# %% [markdown]
# Description of the dataset:
# - ATP: Tournament number
# - Location: Venue of tournament
# - Tournament: Name of tournament
# - Date: Date of match
# - Series: Name of ATP tennis series
# - Court: Type of court
# - Surface: Type of surface
# - Round: Round of match
# - Best of: Maximum number of sets playable in match
# - Winner: Match winner
# - Loser: Match loser
# - WRank: ATP Entry ranking of the match winner as of the start of the tournament
# - LRank: ATP Entry ranking of the match loser as of the start of the tournament
# - WPts: ATP Entry points of the match winner as of the start of the tournament
# - LPts: ATP Entry points of the match loser as of the start of the tournament
# - W1: Number of games won in 1st set by match winner
# - L1: Number of games won in 1st set by match loser
# - W2: Number of games won in 2nd set by match winner
# - L2: Number of games won in 2nd set by match loser
# - W3: Number of games won in 3rd set by match winner
# - L3: Number of games won in 3rd set by match loser
# - W4: Number of games won in 4th set by match winner
# - L4: Number of games won in 4th set by match loser
# - W5: Number of games won in 5th set by match winner
# - L5: Number of games won in 5th set by match loser
# - Wsets: Number of sets won by match winner
# - Lsets: Number of sets won by match loser
# - Comment: Comment on the match (Completed, won through retirement of loser, or via Walkover)
# - B365W: Bet365 odds of match winner
# - B365L: Bet365 odds of match loser
# - PSW: Bet&Win odds of match winner
# - PSL: Bet&Win odds of match loser
# - MaxW: Maximum odds of match winner
# - MaxL: Maximum odds of match loser
# - AvgW: Average odds of match winner
# - AvgL: Average odds of match loser
# - EXW: Expekt odds of match winner
# - EXL: Expekt odds of match loser
# - LBW: Ladbrokes odds of match winner
# - LBL: Ladbrokes odds of match loser
# - SJW: Stan James odds of match winner
# - SJL: Stan James odds of match loser
# - UBW: Unibet odds of match winner
# - UBL: Unibet odds of match loser
# - pl1_flag: Winners Nationality
# - pl1_year_pro: Winners starting year as a pro
# - pl1_weight: Winners weight
# - pl1_height: Winners height
# - pl1_hand: Winners playing hand
# - pl2_flag: Losers Nationality
# - pl2_year_pro: Losers starting year as a pro
# - pl2_weight: Winners weight
# - pl2_height: Losers height
# - pl2_hand: Losers playing hand

# %%
df = pd.read_csv("tennis_data.csv")
print(df.shape)
df
# Out:
# (36120, 54)
# /Users/assiaouanaya/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (36) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        ATP  Location                Tournament        Date       Series  \
# 0        1  Adelaide  Adelaide International 1  2022-01-03       ATP250
# 1        1  Adelaide  Adelaide International 1  2022-01-03       ATP250
# 2        1  Adelaide  Adelaide International 1  2022-01-03       ATP250
# 3        1  Adelaide  Adelaide International 1  2022-01-03       ATP250
# 4        1  Adelaide  Adelaide International 1  2022-01-04       ATP250
# ...    ...       ...                       ...         ...          ...
# 36115   65  Shanghai               Masters Cup  2008-11-14  Masters Cup
# 36116   65  Shanghai               Masters Cup  2008-11-14  Masters Cup
# 36117   65  Shanghai               Masters Cup  2008-11-15  Masters Cup
# 36118   65  Shanghai               Masters Cup  2008-11-15  Masters Cup
# 36119   65  Shanghai               Masters Cup  2008-11-16  Masters Cup
#
#          Court Surface        Round  Best of        Winner  ... pl1_flag  \
# 0      Outdoor    Hard    1st Round        3     Kwon S.W.  ...      KOR
# 1      Outdoor    Hard    1st Round        3   Monteiro T.  ...      BRA
# 2      Outdoor    Hard    1st Round        3      Djere L.  ...      SRB
# 3      Outdoor    Hard    1st Round        3    Johnson S.  ...      USA
# 4      Outdoor    Hard    1st Round        3     Moutet C.  ...      FRA
# ...        ...     ...          ...      ...           ...  ...      ...
# 36115   Indoor    Hard  Round Robin        3      Simon G.  ...      FRA
# 36116   Indoor    Hard  Round Robin        3     Murray A.  ...      GBR
# 36117   Indoor    Hard   Semifinals        3   Djokovic N.  ...      SRB
# 36118   Indoor    Hard   Semifinals        3  Davydenko N.  ...      RUS
# 36119   Indoor    Hard    The Final        3   Djokovic N.  ...      SRB
#
#        pl1_year_pro  pl1_weight  pl1_height      pl1_hand  pl2_flag  \
# 0            2015.0        72.0       180.0  Right-Handed       JPN
# 1            2011.0        78.0       183.0   Left-Handed       GER
# 2            2013.0        80.0       185.0  Right-Handed       ESP
# 3            2012.0        86.0       188.0  Right-Handed       AUS
# 4            2016.0        71.0       175.0   Left-Handed       DEN
# ...             ...         ...         ...           ...       ...
# 36115        2002.0        70.0       183.0  Right-Handed       CZE
# 36116        2005.0        84.0       191.0  Right-Handed       SUI
# 36117        2003.0        77.0       188.0  Right-Handed       FRA
# 36118        1999.0        70.0       178.0  Right-Handed       GBR
# 36119        2003.0        77.0       188.0  Right-Handed       RUS
#
#        pl2_year_pro  pl2_weight  pl2_height      pl2_hand
# 0            2014.0        64.0       170.0   Left-Handed
# 1            2014.0        80.0       188.0  Right-Handed
# 2            2011.0        76.0       180.0  Right-Handed
# 3            2018.0        85.0       188.0  Right-Handed
# 4            2020.0        77.0       188.0  Right-Handed
# ...             ...         ...         ...           ...
# 36115        1996.0        76.0       185.0  Right-Handed
# 36116        1998.0        85.0       185.0  Right-Handed
# 36117        2002.0        70.0       183.0  Right-Handed
# 36118        2005.0        84.0       191.0  Right-Handed
# 36119        1999.0        70.0       178.0  Right-Handed
#
# [36120 rows x 54 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
#        'Lsets', 'Comment', 'B365W', 'B365L', 'PSW', 'PSL', 'MaxW', 'MaxL',
#        'AvgW', 'AvgL', 'EXW', 'EXL', 'LBW', 'LBL', 'SJW', 'SJL', 'UBW', 'UBL',
#        'pl1_flag', 'pl1_year_pro', 'pl1_weight', 'pl1_height', 'pl1_hand',
#        'pl2_flag', 'pl2_year_pro', 'pl2_weight', 'pl2_height', 'pl2_hand'],
#       dtype='object')

# %% [markdown]
# As we are not interested in the betting odds columns we will drop them before any further analysis. The columns in question are the following:
# - B365W: Bet365 odds of match winner
# - B365L: Bet365 odds of match loser
# - PSW: Bet&Win odds of match winner
# - PSL: Bet&Win odds of match loser
# - MaxW: Maximum odds of match winner
# - MaxL: Maximum odds of match loser
# - AvgW: Average odds of match winner
# - AvgL: Average odds of match loser
# - EXW: Expekt odds of match winner
# - EXL: Expekt odds of match loser
# - LBW: Ladbrokes odds of match winner
# - LBL: Ladbrokes odds of match loser
# - SJW: Stan James odds of match winner
# - SJL: Stan James odds of match loser
# - UBW: Unibet odds of match winner
# - UBL: Unibet odds of match loser

# %%
df[['B365W', "B365L", "PSW", "PSL", "MaxW", "MaxL", "AvgW", "AvgL", "EXW", "EXL", "LBW", "LBL", "SJW", "SJL", "UBW", "UBL"]].describe()
# Out:
#               B365W         B365L           PSW           PSL          MaxW  \
# count  35914.000000  35937.000000  33173.000000  33173.000000  29706.000000
# mean       1.839653      3.685053      1.927658      4.117603      2.000127
# std        1.189168      3.884496      1.328985      5.316389      1.543608
# min        0.971000      0.967000      0.974000      1.010000      1.010000
# 25%        1.220000      1.720000      1.273000      1.790000      1.300000
# 50%        1.500000      2.500000      1.560000      2.620000      1.600000
# 75%        2.100000      4.000000      2.150000      4.190000      2.230000
# max       34.000000    101.000000     46.000000    121.000000     76.000000
#
#                MaxL         AvgW          AvgL           EXL           LBW  \
# count  29706.000000  29706.00000  29706.000000  28717.000000  28131.000000
# mean       7.281340      1.84180      3.514055      3.323456      1.810226
# std      347.601852      1.08103      3.191139      2.542908      1.031691
# min        1.010000      1.01000      1.010000      1.000000      1.000000
# 25%        1.830000      1.25000      1.730000      1.730000      1.250000
# 50%        2.730000      1.52000      2.510000      2.500000      1.500000
# 75%        4.390000      2.08000      3.870000      3.800000      2.000000
# max    42586.000000     23.45000     36.440000     40.000000     26.000000
#
#                 LBL           SJW           SJL          UBW          UBL
# count  28142.000000  15572.000000  15579.000000  5309.000000  5309.000000
# mean       3.451461      1.796538      3.557943     1.819319     3.567555
# std        3.075889      1.004273      3.272510     1.038893     3.412837
# min        1.000000      1.000000      1.010000     1.010000     1.020000
# 25%        1.730000      1.220000      1.730000     1.230000     1.750000
# 50%        2.500000      1.500000      2.630000     1.500000     2.520000
# 75%        4.000000      2.000000      4.000000     2.030000     4.000000
# max       51.000000     19.000000     81.000000    18.000000    50.000000

# %%
df.drop(inplace=True, columns=["PSW", "PSL", "MaxW", "MaxL", "AvgW", "AvgL", "EXW", "EXL", "LBW", "LBL", "SJW", "SJL", "UBW", "UBL"])
df.shape
# Out:
# (36120, 40)

# %%
#df.drop(inplace=True, columns=['W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets'])
#df.shape

# %% [markdown]
# Let's check the number of NA values in the dataset's columns and handle them.

# %%
df.isna().sum()
# Out:
# ATP                 0
# Location            0
# Tournament          0
# Date                0
# Series              0
# Court               0
# Surface             0
# Round               0
# Best of             0
# Winner              0
# Loser               0
# WRank              13
# LRank              80
# WPts               11
# LPts               79
# W1                232
# L1                229
# W2                571
# L2                571
# W3              19076
# L3              19076
# W4              32677
# L4              32677
# W5              34825
# L5              34825
# Wsets             231
# Lsets             234
# Comment             0
# B365W             206
# B365L             183
# pl1_flag           96
# pl1_year_pro       96
# pl1_weight         96
# pl1_height         96
# pl1_hand           96
# pl2_flag          649
# pl2_year_pro      649
# pl2_weight        649
# pl2_height        649
# pl2_hand          649
# dtype: int64

# %%
df.dropna(axis=0, subset=['pl1_flag', 'pl2_flag', 'WRank', 'LRank', 'WPts', 'LPts'], inplace=True)
df.shape
# Out:
# (35377, 40)

# %%
df.dropna(axis=0, subset=['pl1_flag', 'pl2_flag'], inplace=True)
df.isna().sum()
# Out:
# ATP                 0
# Location            0
# Tournament          0
# Date                0
# Series              0
# Court               0
# Surface             0
# Round               0
# Best of             0
# Winner              0
# Loser               0
# WRank               0
# LRank               0
# WPts                0
# LPts                0
# W1                231
# L1                228
# W2                567
# L2                567
# W3              18599
# L3              18599
# W4              31978
# L4              31978
# W5              34095
# L5              34095
# Wsets             230
# Lsets             233
# Comment             0
# B365W             193
# B365L             171
# pl1_flag            0
# pl1_year_pro        0
# pl1_weight          0
# pl1_height          0
# pl1_hand            0
# pl2_flag            0
# pl2_year_pro        0
# pl2_weight          0
# pl2_height          0
# pl2_hand            0
# dtype: int64

# %% [markdown]
# Now let's investigate our numerical features.

# %%
df.describe()
# Out:
#                 ATP       Best of         WRank         LRank          WPts  \
# count  35377.000000  35377.000000  35377.000000  35377.000000  35377.000000
# mean      31.720723      3.395455     56.766713     83.366622   1993.128530
# std       18.022301      0.796582     69.786739     96.106565   2420.985833
# min        1.000000      3.000000      1.000000      1.000000      1.000000
# 25%       18.000000      3.000000     16.000000     34.000000    706.000000
# 50%       31.000000      3.000000     40.000000     62.000000   1090.000000
# 75%       48.000000      3.000000     75.000000    100.000000   2075.000000
# max       67.000000      5.000000   1890.000000   1890.000000  16950.000000
#
#                LPts            W1            L1            W2            L2  \
# count  35377.000000  35146.000000  35149.000000  34810.000000  34810.000000
# mean    1159.382367      5.803050      4.106262      5.783108      3.944441
# std     1307.405901      1.231894      1.829837      1.249189      1.860474
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%      562.000000      6.000000      3.000000      6.000000      3.000000
# 50%      815.000000      6.000000      4.000000      6.000000      4.000000
# 75%     1240.000000      6.000000      6.000000      6.000000      6.000000
# max    16950.000000      7.000000      7.000000      7.000000      7.000000
#
#        ...         Wsets         Lsets         B365W         B365L  \
# count  ...  35147.000000  35144.000000  35184.000000  35206.000000
# mean   ...      2.155831      0.418621      1.849004      3.621398
# std    ...      0.464083      0.563051      1.195452      3.759611
# min    ...      0.000000      0.000000      0.971000      0.967000
# 25%    ...      2.000000      0.000000      1.250000      1.660000
# 50%    ...      2.000000      0.000000      1.500000      2.500000
# 75%    ...      2.000000      1.000000      2.100000      4.000000
# max    ...      3.000000      2.000000     34.000000     67.000000
#
#        pl1_year_pro    pl1_weight    pl1_height  pl2_year_pro    pl2_weight  \
# count  35377.000000  35377.000000  35377.000000  35377.000000  35377.000000
# mean    2005.005371     80.878367    187.003873   2005.077451     79.958137
# std        5.177058      7.891915     12.092681     11.856877      7.518406
# min     1989.000000      7.000000     10.000000      0.000000      7.000000
# 25%     2001.000000     75.000000    183.000000   2001.000000     75.000000
# 50%     2004.000000     80.000000    185.000000   2005.000000     80.000000
# 75%     2008.000000     85.000000    191.000000   2008.000000     84.000000
# max     2021.000000    108.000000   1883.000000   2021.000000    108.000000
#
#          pl2_height
# count  35377.000000
# mean     186.340871
# std       19.810576
# min       10.000000
# 25%      183.000000
# 50%      185.000000
# 75%      191.000000
# max     1883.000000
#
# [8 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35377 entries, 0 to 36119
# Data columns (total 40 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ATP           35377 non-null  int64
#  1   Location      35377 non-null  object
#  2   Tournament    35377 non-null  object
#  3   Date          35377 non-null  object
#  4   Series        35377 non-null  object
#  5   Court         35377 non-null  object
#  6   Surface       35377 non-null  object
#  7   Round         35377 non-null  object
#  8   Best of       35377 non-null  int64
#  9   Winner        35377 non-null  object
#  10  Loser         35377 non-null  object
#  11  WRank         35377 non-null  float64
#  12  LRank         35377 non-null  float64
#  13  WPts          35377 non-null  float64
#  14  LPts          35377 non-null  float64
#  15  W1            35146 non-null  float64
#  16  L1            35149 non-null  float64
#  17  W2            34810 non-null  float64
#  18  L2            34810 non-null  float64
#  19  W3            16778 non-null  float64
#  20  L3            16778 non-null  float64
#  21  W4            3399 non-null   float64
#  22  L4            3399 non-null   float64
#  23  W5            1282 non-null   float64
#  24  L5            1282 non-null   float64
#  25  Wsets         35147 non-null  float64
#  26  Lsets         35144 non-null  float64
#  27  Comment       35377 non-null  object
#  28  B365W         35184 non-null  float64
#  29  B365L         35206 non-null  float64
#  30  pl1_flag      35377 non-null  object
#  31  pl1_year_pro  35377 non-null  float64
#  32  pl1_weight    35377 non-null  float64
#  33  pl1_height    35377 non-null  float64
#  34  pl1_hand      35377 non-null  object
#  35  pl2_flag      35377 non-null  object
#  36  pl2_year_pro  35377 non-null  float64
#  37  pl2_weight    35377 non-null  float64
#  38  pl2_height    35377 non-null  float64
#  39  pl2_hand      35377 non-null  object
# dtypes: float64(24), int64(2), object(14)
# memory usage: 11.1+ MB

# %%
df.loc['Sched']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Sched'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/q2/625j9bfn7rxbjv61_zf0fc_40000gn/T/ipykernel_14841/3637183530.py in <module>
# ----> 1 df.loc['Sched']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Sched'

# %%
df.plot.box(subplots=True, figsize=(20,15), layout=(3,4))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/q2/625j9bfn7rxbjv61_zf0fc_40000gn/T/ipykernel_14841/2754367908.py in <module>
# ----> 1 df.plot.box(subplots=True, figsize=(20,15), layout=(3,4))
#       2 plt.tight_layout()
#       3 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in box(self, by, **kwargs)
#    1264             >>> ax = df.plot.box()
#    1265         """
# -> 1266         return self(kind="box", by=by, **kwargs)
#    1267
#    1268     def hist(self, by=None, bins=10, **kwargs):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     285         self._args_adjust()
#     286         self._compute_plot_data()
# --> 287         self._setup_subplots()
#     288         self._make_plot()
#     289         self._add_table()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in _setup_subplots(self)
#     332     def _setup_subplots(self):
#     333         if self.subplots:
# --> 334             fig, axes = create_subplots(
#     335                 naxes=self.nseries,
#     336                 sharex=self.sharex,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     257             fig.clear()
#     258
# --> 259     nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#     260     nplots = nrows * ncols
#     261
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/tools.py in _get_layout(nplots, layout, layout_type)
#      95
#      96         if nrows * ncols < nplots:
# ---> 97             raise ValueError(
#      98                 f"Layout of {nrows}x{ncols} must be larger than required size {nplots}"
#      99             )
#
# ValueError: Layout of 3x4 must be larger than required size 26

# %% [markdown]
# We notice there are a lot of outliers in the following columns:
# - WRank: ATP Entry ranking of the match winner as of the start of the tournament
# - LRank: ATP Entry ranking of the match loser as of the start of the tournament
# - WPts: ATP Entry points of the match winner as of the start of the tournament
# - LPts: ATP Entry points of the match loser as of the start of the tournament
#
# We also see that the Best of (accounting for number of sets per match) is a binary value.

# %%
df['Best of'].unique()
# Out:
# array([3, 5])

# %% [markdown]
# Let's check if there any correlation between any of the columns.

# %%
df.corr()
# Out:
#                    ATP   Best of     WRank     LRank      WPts      LPts  \
# ATP           1.000000 -0.040426 -0.038902 -0.039708  0.031047  0.060345
# Best of      -0.040426  1.000000 -0.073942  0.007127  0.132261  0.003425
# WRank        -0.038902 -0.073942  1.000000  0.110108 -0.418702 -0.124845
# LRank        -0.039708  0.007127  0.110108  1.000000 -0.131140 -0.392384
# WPts          0.031047  0.132261 -0.418702 -0.131140  1.000000  0.242517
# LPts          0.060345  0.003425 -0.124845 -0.392384  0.242517  1.000000
# pl1_year_pro -0.030682 -0.008905  0.104485 -0.000968 -0.123227  0.013176
# pl1_weight    0.024094  0.025494 -0.085206 -0.023531  0.096934  0.043907
# pl1_height    0.023009  0.009138 -0.037404 -0.016406  0.035083  0.026795
# pl2_year_pro -0.010975 -0.002944  0.012252  0.031685 -0.005357 -0.015393
# pl2_weight    0.028496 -0.002220 -0.027012 -0.050017  0.048077  0.114412
# pl2_height    0.011222 -0.007428 -0.005800 -0.008298  0.013632  0.029406
#
#               pl1_year_pro  pl1_weight  pl1_height  pl2_year_pro  pl2_weight  \
# ATP              -0.030682    0.024094    0.023009     -0.010975    0.028496
# Best of          -0.008905    0.025494    0.009138     -0.002944   -0.002220
# WRank             0.104485   -0.085206   -0.037404      0.012252   -0.027012
# LRank            -0.000968   -0.023531   -0.016406      0.031685   -0.050017
# WPts             -0.123227    0.096934    0.035083     -0.005357    0.048077
# LPts              0.013176    0.043907    0.026795     -0.015393    0.114412
# pl1_year_pro      1.000000    0.032769    0.108927      0.188979   -0.031560
# pl1_weight        0.032769    1.000000    0.474027     -0.012917    0.016343
# pl1_height        0.108927    0.474027    1.000000      0.012210    0.006732
# pl2_year_pro      0.188979   -0.012917    0.012210      1.000000    0.022188
# pl2_weight       -0.031560    0.016343    0.006732      0.022188    1.000000
# pl2_height        0.011203   -0.001605   -0.000831      0.026952    0.281835
#
#               pl2_height
# ATP             0.011222
# Best of        -0.007428
# WRank          -0.005800
# LRank          -0.008298
# WPts            0.013632
# LPts            0.029406
# pl1_year_pro    0.011203
# pl1_weight     -0.001605
# pl1_height     -0.000831
# pl2_year_pro    0.026952
# pl2_weight      0.281835
# pl2_height      1.000000

# %% [markdown]
# It seems there no high correlation between the dataset columns.

# %% [markdown]
# Let's see if there is any 0-standard deviation column.

# %%
df.std(numeric_only=True)
# Out:
# ATP               18.022301
# Best of            0.796582
# WRank             69.786739
# LRank             96.106565
# WPts            2420.985833
# LPts            1307.405901
# pl1_year_pro       5.177058
# pl1_weight         7.891915
# pl1_height        12.092681
# pl2_year_pro      11.856877
# pl2_weight         7.518406
# pl2_height        19.810576
# dtype: float64

# %% [markdown]
# All of the columns have non-null standard deviation accounting that all columns are interesting to use in our analysis.

# %% [markdown]
# What are the non-numerical features of the dataset?

# %%
print(df.select_dtypes(exclude=np.number).head(4).columns)
df.select_dtypes(exclude=np.number).head(4)
# Out:
# Index(['Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round',
#        'Winner', 'Loser', 'Comment', 'pl1_flag', 'pl1_hand', 'pl2_flag',
#        'pl2_hand'],
#       dtype='object')
#    Location                Tournament        Date  Series    Court Surface  \
# 0  Adelaide  Adelaide International 1  2022-01-03  ATP250  Outdoor    Hard
# 1  Adelaide  Adelaide International 1  2022-01-03  ATP250  Outdoor    Hard
# 2  Adelaide  Adelaide International 1  2022-01-03  ATP250  Outdoor    Hard
# 3  Adelaide  Adelaide International 1  2022-01-03  ATP250  Outdoor    Hard
#
#        Round       Winner               Loser    Comment pl1_flag  \
# 0  1st Round    Kwon S.W.         Nishioka Y.  Completed      KOR
# 1  1st Round  Monteiro T.         Altmaier D.  Completed      BRA
# 2  1st Round     Djere L.  Carballes Baena R.  Completed      SRB
# 3  1st Round   Johnson S.            Vukic A.  Completed      USA
#
#        pl1_hand pl2_flag      pl2_hand
# 0  Right-Handed      JPN   Left-Handed
# 1   Left-Handed      GER  Right-Handed
# 2  Right-Handed      ESP  Right-Handed
# 3  Right-Handed      AUS  Right-Handed

# %% [markdown]
# What are the different locations we have?

# %%
df.Location.unique()
# Out:
# array(['Adelaide', 'Melbourne', 'Sydney', 'Cordoba', 'Montpellier',
#        'Pune', 'Buenos Aires', 'Dallas', 'Rotterdam', 'Delray Beach',
#        'Doha', 'Marseille', 'Rio de Janeiro', 'Acapulco', 'Dubai ',
#        'Santiago', 'Antalya', 'Singapore', 'Miami', 'Cagliari',
#        'Marbella', 'Monte Carlo', 'Barcelona', 'Belgrade', 'Estoril',
#        'Munich', 'Madrid', 'Rome', 'Geneva', 'Lyon', 'Parma', 'Paris',
#        'Stuttgart', 'Halle', 'Queens Club', 'Eastbourne', 'Mallorca',
#        'London', 'Bastad', 'Hamburg', 'Newport', 'Gstaad', 'Los Cabos',
#        'Umag', 'Atlanta', 'Kitzbuhel', 'Washington', 'Toronto',
#        'Cincinnati', 'Winston-Salem', 'New York', 'Metz', 'Nur-Sultan',
#        'San Diego', 'Sofia', 'Indian Wells', 'Antwerp', 'Moscow',
#        'St. Petersburg', 'Vienna', 'Stockholm', 'Turin', 'Auckland',
#        'Cologne', 'Sardinia', 'Brisbane', 'Sao Paulo', 'Houston',
#        'Marrakech', 'Budapest', "'s-Hertogenbosch", 'Montreal', 'Chengdu',
#        'Zhuhai', 'Beijing', 'Tokyo', 'Shanghai', 'Basel', 'Quito',
#        'Istanbul', 'Shenzhen ', 'Chennai', 'Memphis', 'Bucharest', 'Nice',
#        'Nottingham', 'Zagreb', 'Casablanca', 'Bogota', 'Kuala Lumpur',
#        'Valencia', 'Vina del Mar', 'Oeiras', 'Dusseldorf', 'San Jose',
#        'Bangkok', 'Estoril ', 'Los Angeles', 'Johannesburg ',
#        'Costa Do Sauipe', 'New Haven', 'Indianapolis', 'Las Vegas',
#        'Portschach', 'Warsaw', 'Amersfoort'], dtype=object)

# %%
pd.DataFrame(df.groupby('Location').count().sort_values(by='ATP',ascending=False)['ATP'])
# Out:
#                ATP
# Location
# Paris         2428
# Melbourne     1999
# New York      1886
# London        1809
# Indian Wells  1234
# ...            ...
# Cagliari        26
# Zhuhai          26
# Singapore       24
# Amersfoort      23
# Turin           15
#
# [106 rows x 1 columns]

# %% [markdown]
# What are different tennis tournaments?

# %%
df.Tournament.unique()
# Out:
# array(['Adelaide International 1', 'Melbourne Summer Set',
#        'Adelaide International 2', 'Sydney Tennis Classic',
#        'Australian Open', 'Cordoba Open', 'Open Sud de France',
#        'Maharashtra Open', 'Argentina Open', 'Dallas Open',
#        'ABN AMRO World Tennis Tournament', 'Delray Beach Open',
#        'Qatar Exxon Mobil Open', 'Open 13', 'Rio Open',
#        'Abierto Mexicano', 'Dubai Tennis Championships', 'Chile Open',
#        'Antalya Open', 'Great Ocean Road Open', 'Murray River Open',
#        'Singapore Open', 'Miami Open', 'Sardegna Open',
#        'AnyTech365 Andalucia Open', 'Monte Carlo Masters',
#        'Barcelona Open', 'Serbia Open', 'Millennium Estoril Open',
#        'BMW Open', 'Mutua Madrid Open', "Internazionali BNL d'Italia",
#        'Geneva Open', 'Lyon Open', 'Belgrade Open', 'Emilia-Romagna Open',
#        'French Open', 'Mercedes Cup', 'Halle Open',
#        "Queen's Club Championships", 'Viking International',
#        'Mallorca Championships', 'Wimbledon', 'Nordea Open',
#        'European Open', 'Hall of Fame Championships',
#        'Suisse Open Gstaad', 'Mifel Open', 'Croatia Open',
#        'BB&T Atlanta Open', 'Generali Open', 'Citi Open', 'Canadian Open',
#        'Western & Southern Financial Group Masters',
#        'Winston-Salem Open at Wake Forest University', 'US Open',
#        'Open de Moselle', 'Astana Open', 'San Diego Open', 'Sofia Open',
#        'BNP Paribas Open', 'Kremlin Cup', 'St. Petersburg Open',
#        'Vienna Open', 'BNP Paribas Masters', 'Stockholm Open',
#        'Masters Cup', 'ASB Classic', 'Adelaide International',
#        'New York Open', 'German Tennis Championships',
#        'bett1HULKS Indoors', 'Forte Village Sardegna Open',
#        'bett1HULKS Championship', 'Erste Bank Open',
#        'Brisbane International', 'Sydney International', 'Brasil Open',
#        'Sony Ericsson Open', "U.S. Men's Clay Court Championships",
#        'Grand Prix Hassan II', 'Open Banco Sabadell ', 'Hungarian Open',
#        'Rosmalen Grass Court Championships', 'Eastbourne International',
#        'SkiStar Swedish Open', 'Abierto Mexicano Mifel', 'Rogers Masters',
#        'Chengdu Open', 'Zhuhai Open', 'China Open',
#        'Rakuten Japan Open Tennis Championships', 'Shanghai Masters',
#        'Swiss Indoors', 'Tata Open', 'Ecuador Open',
#        'Garanti Koza Sofia Open', 'Gazprom Hungarian Open',
#        'Istanbul Open', 'Ricoh Open', 'Gerry Weber Open',
#        'AEGON Championships', 'Shenzhen Open', 'Chennai Open',
#        'Apia International', 'Memphis Open', 'Millenium Estoril Open',
#        'AEGON International', 'Open Banco Sabadell',
#        'BRD Nastase Tiriac Trophy', 'Open de Nice Côte d’Azur',
#        'Topshelf Open', 'AEGON Open', 'Konzum Croatia Open',
#        'Heineken Open', 'PBZ Zagreb Indoors', 'Claro Open Colombia',
#        'bet-at-home Open', 'Malaysian Open', 'Valencia Open 500',
#        'Royal Guard Open Chile', 'Copa Claro',
#        'U.S. National Indoor Tennis Championships', 'Portugal Open',
#        'Dusseldorf Open', 'Crédit Agricole Suisse Open Gstaad',
#        'ATP Vegeta Croatia Open', 'Bet-At-Home Cup', 'VTR Open',
#        'SAP Open', 'International Championships', 'Power Horse Cup',
#        'German Open Tennis Championships', 'Thailand Open',
#        'Regions Morgan Keegan Championships', 'Estoril Open',
#        'Unicef Open', 'Farmers Classic', 'Medibank International',
#        'SA Tennis Open', 'Movistar Open', 'Mutua Madrileña Madrid Open',
#        'Atlanta Tennis Championships', 'Allianz Suisse Open',
#        'Studena Croatia Open', 'Legg Mason Classic', 'Open Romania',
#        'Copa Telmex', 'Pilot Pen Tennis', 'Proton Malaysian Open',
#        'BA-CA Tennis Trophy', 'Austrian Open', 'Ordina Open',
#        'Catella Swedish Open', 'International German Open',
#        'Indianapolis Tennis Championships', 'LA Tennis Open',
#        'Grand Prix de Lyon', 'Davidoff Swiss Indoors',
#        'Next Generation Adelaide International', 'Channel Open',
#        'Pacific Life Open', 'Open de Tenis Comunidad Valenciana',
#        'Open Sabadell Atlántico 2008', 'Hamburg TMS',
#        'Hypo Group Tennis International', 'Stella Artois',
#        'Orange Prokom Open', 'Slazenger Open', 'Dutch Open',
#        'Countrywide Classic', 'AIG Japan Open Tennis Championships',
#        'Madrid Masters', 'BNP Paribas'], dtype=object)

# %%
pd.DataFrame(df.groupby('Tournament').count().sort_values(by='ATP',ascending=False)['ATP'])
# Out:
#                       ATP
# Tournament
# Australian Open      1871
# French Open          1754
# US Open              1753
# Wimbledon            1629
# BNP Paribas Open     1139
# ...                   ...
# Belgrade Open          25
# Mifel Open             25
# Singapore Open         24
# Countrywide Classic    24
# Dutch Open             23
#
# [174 rows x 1 columns]

# %% [markdown]
# Who are the top 5 players that won the highest number of matches?

# %%
pd.DataFrame(df.groupby('Winner').agg('count').sort_values(by='ATP', ascending=False).head(5)['ATP'])
# Out:
#              ATP
# Winner
# Djokovic N.  824
# Nadal R.     757
# Federer R.   673
# Murray A.    564
# Ferrer D.    498

# %% [markdown]
# Who are the 5 players that lost the highest number of matches?

# %%
pd.DataFrame(df.groupby('Loser').agg('count').sort_values(by='ATP', ascending=False).head(5)['ATP'])
# Out:
#              ATP
# Loser
# Seppi A.     316
# Simon G.     315
# Fognini F.   314
# Verdasco F.  311
# Lopez F.     308

# %% [markdown]
# Which type of court is more popular?

# %%
pd.DataFrame(df.groupby('Court').count()['ATP'])
# Out:
#            ATP
# Court
# Indoor    6405
# Outdoor  28972

# %%
pd.DataFrame(df.groupby('Surface').count()['ATP'])
# Out:
#            ATP
# Surface
# Carpet     226
# Clay     10969
# Grass     3945
# Hard     20237

# %% [markdown]
# What are the different of comments?

# %%
df.Comment.unique()
# Out:
# array(['Completed', 'Retired', 'Walkover', 'Awarded', 'Rrtired',
#        'Disqualified', 'Sched'], dtype=object)

# %% [markdown]
# We see that there are a typo, let's fix it.

# %%
df.replace('Rrtired', value = 'Retired', inplace=True)

# %%
df.Comment.unique()
# Out:
# array(['Completed', 'Retired', 'Walkover', 'Awarded', 'Disqualified',
#        'Sched'], dtype=object)

# %% [markdown]
# What are the status of the matches?

# %%
pd.DataFrame(df.groupby('Comment').count()['ATP'])
# Out:
#                 ATP
# Comment
# Awarded           2
# Completed     34025
# Disqualified      2
# Retired        1126
# Sched             1
# Walkover        221

# %% [markdown]
# Which nationality wins the most in the tennis field?

# %%
pd.DataFrame(df.groupby('pl1_flag').count().sort_values(by='ATP', ascending=False)['ATP']).head(10)
# Out:
#            ATP
# pl1_flag
# ESP       4724
# FRA       3787
# USA       3008
# GER       2154
# ARG       2031
# SRB       1685
# RUS       1648
# ITA       1559
# CRO       1204
# SUI       1196

# %% [markdown]
# Which nationality loses the most in the tennis field?

# %%
pd.DataFrame(df.groupby('pl2_flag').count().sort_values(by='ATP', ascending=False)['ATP']).head(10)
# Out:
#            ATP
# pl2_flag
# ESP       3907
# FRA       3747
# USA       3203
# GER       2502
# ARG       2099
# ITA       1871
# RUS       1602
# AUS       1365
# SRB       1039
# CRO        996

# %% [markdown]
# Right-handed vs Left-handed ?

# %%
pd.DataFrame(df.groupby('pl1_hand').count()['ATP'])
# Out:
#                 ATP
# pl1_hand
# Left-Handed    4705
# Right-Handed  30672

# %%
pd.DataFrame(df.groupby('pl2_hand').count()['ATP'])
# Out:
#                 ATP
# pl2_hand
# Left-Handed    5019
# Right-Handed  30358

# %% [markdown]
# TO DO AFTER EDA :
# - link player names with players images
# - link flag names with flag images
# - see if needed to turn non-numerical features to dummy variables
# - normalize ?

# %% [markdown]
# ## Related work/Our ideas

# %% [markdown]
# These data are usually presented in a very classical way in the form of tables detailing the statistics of the players according to different criteria as can be seen on these two reference sites: http://www.tennisabstract.com/cgi-bin/leaders.cgi?f=B0s00o1 or https://www.atptour.com/en/stats.
#
# Our idea is original in the sense that it aims to show much more the links between players and countries. The way of approaching the data is therefore different. Our ambitions for the moment are as follows:
#
# - ***Tab 1*: Network between players:**
#     - Make a network that connects players who have played a match. Interactivity: you can move the nodes with the mouse to make the network move.
#     - A node corresponds to a player (with the picture of the player in the node). The bigger the node, the more matches the player has made.
#     - Network oriented to know who is the winner.
#     - Slider to choose the year.
#     - Button to apply filters according to different variables: Location, Tournament, Serie, Court, Surface, Players ranking range.
#     - When hovering a summary of information is displayed with a possibility to click on an extension. This extension is a whole page about the player is displayed with: his picture, the number of matches played in ATP by series per year, the number of wins and the number of losses according to the year/the tournament/the type of court/the type of surface, his nationality, his weight, his year of start as a pro and his playing hand. There is also a planisphere that can be rotated and where the points of the tournaments in which he participated by year are displayed (inspiration: https://observablehq.com/@d3/world-tour or https://observablehq.com/@d3/versor-dragging). Also, a list with his main opponents.
#     - It is also possible to click on the link between the two players: a box is displayed with the characteristics of the matches: their photo, location, tournament, date, series, court, surface, round, winner, rank and points of the players at the beginning of the tournament, number of games won by each player for each set, number of sets won by each player, comment, odds.
#     - Inspiration: http://www.claudiobellei.com/2017/02/04/viznetworks/
#
#
# - ***Tab 2*: Connection map between countries:**
#     - World map with the countries colored according to for example the number of victories of theirs players.
#     - Link between the countries whose players play each other in a match.
#     - Slider to choose the year.
#     - Button to apply filters according to different variables: Location, Tournament, Serie, Court, Surface, Players ranking range.
#     - Possibility to click on a country: a box appears with the list of players of the country and the number of matches of each one for this year with their number of victories.
#     - You can also click on the links between the countries: a box with the characteristics of the match is displayed with : location, tournament, date, series, court, surface, round, winner, rank and points of the players at the beginning of the tournament, number of games won by each for each set, number of sets won by each, comment, odds.
#     - Inspiration: https://d3-graph-gallery.com/graph/connectionmap_multi.html
#
#
#
# - ***Tab 3*: Bart Charts with bars that move over time:**
#     - Two bart charts on the same line with the bars moving as the years go by.
#     - A first bart chart to show the evolution of the countries ranking in terms of number of wins.
#     - A second bart chart to show the evolution of the players in terms of number of wins.
#     - Button to apply filters according to different variables: Series, Court, Surface.
#     - Inspiration: https://observablehq.com/@d3/bar-chart-race
#
#
#
#
# - ***(Side ideas for the site)***:
#     - Make the loading symbol in the form of a spinning tennis ball.
#     - Make a mascot in the form of a tennis racket to explain the site's features at the beginning.
#     - Make symbols for the selection of variables, a small cup for the winner, flags for the nationalities, etc...
#
#
# *NB : The dataset is extracted from the Kaggle database (https://www.kaggle.com/datasets/edoardoba/atp-tennis-data) and only a "Djokovic vs Nadal quick analysis" is presented as analysis of this data.*

# %%
winns = pd.Series(df['Winner'].unique())
lose = pd.Series(df['Loser'].unique())
len(winns.append(lose).unique())
# Out:
# 697
